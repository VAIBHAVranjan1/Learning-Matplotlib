# %% [markdown]
# ### This is Phase 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
#resize the graph
plt.figure(figsize= (5, 3), dpi = 9000)

# %%
x = np.arange(1, 10, 1)
y = x*2

plt.plot(x, y, color ='black', label='y = 2x', linewidth=1, marker='.', markersize = 9, markeredgecolor = 'blue', linestyle='-')
plt.title('Graph', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.legend(loc=0)

# %%
x2 = np.arange(0, 4.5, 0.5)
plt.plot(x2, x2**2, 'r', label="X^2")
plt.legend()

# Saving the graph
plt.savefig('mygraph.png',dpi = 1000)

# %% [markdown]
# ### BarChart

# %%
labels = ['A', 'B', 'C', 'D', 'E', 'F']
values = np.arange(1, 7)

bar = plt.bar(labels, values,)
pattern = ['/', 'o', '*', '+', '-', '|', '\\']
i = 0
for each in bar:
    each.set_hatch(pattern[i])
    i += 1

plt.figure(figsize = (6, 4), dpi = 1000)
