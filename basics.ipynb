# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Functional Plot

# %%
x_1 = np.linspace(0, 5, 100)
y_1 = x_1**2
plt.plot(x_1, y_1)
plt.title("Days Squared Charts")
plt.xlabel("Days")
plt.ylabel("Days Squared")
# Out:
# Text(0, 0.5, 'Days Squared')
